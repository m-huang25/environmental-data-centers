# %%
cd /home/user/Capstone/GitHub/data-center-impacts
# Out:
# /home/user/Capstone/GitHub/data-center-impacts

# %%
# !git -C /home/user/Capstone/GitHub rev-parse --show-toplevel
# Out:
# /home/user/Capstone

# %%
# %%bash
#
# # Go to your repo
# cd /home/user/Capstone
#
# # Step 1: Commit the deletion
# git add -A
# git commit -m "Remove notebook with exposed GitHub token"
#
# # Step 2: Create a new clean branch (no history of deleted notebook)
# git checkout --orphan clean-main
# git add -A
# git commit -m "Clean branch without secret notebook"
#
# # Step 3: Force push the clean branch to GitHub main
# git push --force --set-upstream origin clean-main:main
# Out:
# [main 2078ded] Remove notebook with exposed GitHub token
#  1 file changed, 281 insertions(+), 10 dele
# tions(-)
# Switched to a new branch 'clean-main'
# M	data_center_research
# [clean-main (root-commit) b11a577] Clean branch without secret notebook
#  49 files changed, 114975 in
# sertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 GitHub/GitHub_2026_March.ipynb
#  creat
# e mode 100644 GitHub/data-center-impacts/README.md
#  create mode 100644 GitHub/data-center-impacts/da
# ta_center_research/.gitignore
#  create mode 100644 GitHub/data-center-impacts/data_center_research/da
# ta/metadata/README.txt
#  create mode 100644 GitHub/data-center-impacts/data_center_research/data/meta
# data/metadata.md
#  create mode 100644 GitHub/data-center-impacts/data_center_research/data/processed/
# README.txt
#  create mode 100644 GitHub/data-center-impacts/data_center_research/data/processed/active
# _air_sites.csv
# ...
