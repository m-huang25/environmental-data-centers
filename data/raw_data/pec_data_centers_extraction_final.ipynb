# %%
## Retrieving data from PEC website using Python

import requests
import pandas as pd

# Set where file should be saved to:

import os

os.chdir("/home/user/Capstone/data_center_research/data/raw_data")

# %%
# Updated URL with layer 19
url = "https://services3.arcgis.com/mTaShYKffyWc5uRb/arcgis/rest/services/Data_Centers_Virginia/FeatureServer/19/query"

params = {
    "where": "1=1",          # get all rows
    "outFields": "*",        # all columns
    "f": "json",             # specify JSON response
    "returnGeometry": "false"  # no geometry, just the data
}

response = requests.get(url, params=params)

# %%
# Print the raw response to check the content
print("Response Status Code:", response.status_code)
print("Response Text:", response.text[:500])  # Print the first 500 characters
# Out:
# Response Status Code: 200
# Response Text: {"objectIdFieldName":"OBJECTID","uniqueIdField":{"name":"OBJECTID","isSystemMaintained":true},"globalIdFieldName":"","geometryType":"esriGeometryPoint","spatialReference":{"wkid":102100,"latestWkid":3857},"fields":[{"name":"OBJECTID","type":"esriFieldTypeOID","alias":"OBJECTID","sqlType":"sqlTypeOther","domain":null,"defaultValue":null},{"name":"PEC_ID","type":"esriFieldTypeString","alias":"PEC_ID","sqlType":"sqlTypeOther","length":8000,"domain":null,"defaultValue":null},{"name":"Locality","type

# %%
# Try parsing JSON
try:
    data = response.json()
        
# Check if there are any features in the data
    if "features" in data:
        rows = [feature["attributes"] for feature in data["features"]]
        df = pd.DataFrame(rows)
        df.to_csv("pec_data_centers.csv", index=False)
        print("CSV saved!")
        print("Data Sample:\n", df.head())
    else:
        print("No features found in the response. Data may be empty or incorrectly formatted.")
except Exception as e:
    print("Error decoding JSON:", e)
# Out:
# CSV saved!
# Data Sample:
#     OBJECTID                     PEC_ID             Locality  \
# 0         1  PEC-CAR-0001/PEC-SPO-0003      Caroline County
# 1         2               PEC-CAR-0002      Caroline County
# 2         3               PEC-CAR-0003      Caroline County
# 3         4               PEC-CHE-0001  Chesterfield County
# 4         5               PEC-CHE-0002  Chesterfield County
#
#                                        Name               Owner_Applicant  \
# 0                    Mattameade Tech Campus      Amazon Data Services Inc
# 1                    VALCO Data Center Park         VALCO CAROLINE COUNTY
# 2                    Carmel Church Data Hub                W & F PARTNERS
# 3                Digital Fortress: Richmond          CHIRISA RICHMOND LLC
# 4  Virginia Information Technologies Agency  SLK GLOBAL SOLUTIONS AMERICA
#
#                                       Street_Address        Parcel_ID   Acres  \
# 0  Stonewall Jackson Road just east of the Mudd T...          27-A-4A  916.07
# 1                                       Mt Airy Road          80-A-43  855.00
# 2                                      Welcom Way Dr          82-14-A   97.00
# 3                      1401 MEADOWVILLE TECH PARKWAY  823657720300000   74.80
# 4                             11751 MEADOWVILLE LANE  822656429800000   28.14
#
#   Building_Sq_Ft  MW_reported  ... Build_Status  \
# 0      4,500,000          NaN  ...     Proposed
# 1      1,216,000          NaN  ...     Proposed
# 2      1,600,000          NaN  ...     Proposed
# 3        242,042         25.0  ...     Existing
# 4        192,195          NaN  ...     Existing
#
#                                                Notes  \
# 0  Sister property to Spotsylvania campus- repres...
# 1  Project covers more than one parcel, the acrea...
# 2  Project covers more than one parcel, the acrea...
# 3  Formerly a Capital One data center - vacated a...
# 4                                               None
#
#                                         Tax_Map_link  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  https://www.chesterfield.gov/828/Real-Estate-A...
# 4  https://www.chesterfield.gov/828/Real-Estate-A...
#
#                                          Source_link          Lat       Long  \
# 0  https://co.caroline.va.us/DocumentCenter/View/...  38.11464706 -77.491153
# 1  https://co.caroline.va.us/AgendaCenter/ViewFil...  37.92410305 -77.543872
# 2  https://co.caroline.va.us/DocumentCenter/View/...  37.93932712 -77.477973
# 3                                               None  37.36048164 -77.327411
# 4                                               None  37.36041473 -77.331778
#
#    Date_Updated Updated_By       Lat1  Watershed
# 0    2024-04-10        SEP  38.114647       None
# 1    2024-04-10        SEP  37.924103       None
# 2    2024-04-10        SEP  37.939327       None
# 3    2024-04-10        SEP  37.360482       None
# 4    2024-04-10        SEP  37.360415       None
#
# [5 rows x 21 columns]

# %%
# locate where .csv file is saved to
import os
print(os.getcwd())
# Out:
# /home/user/Capstone/data_center_research/data/raw_data
