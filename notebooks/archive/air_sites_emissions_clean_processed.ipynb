# %%
#load library
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.0     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.2     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
setwd("/home/user/Capstone/data_center_research")

# %%
# Import CSV file on air_emissions for the year 2024 in Virginia. 
air_sites_emissions <- read.csv("data/raw_data/Air_Sites_Emissions.csv")

# %%
# Rename variables
air_sites_emissions_clean <- air_sites_emissions %>%
    rename(
      emissions_year = EMISSIONSYEAR,
      emission_value = EMISSION_VALUE,
      icis_id = PLA_ICIS_ID,
      pollutant_name = CPL_POLLUTANT_NAME
    )

# %%
# List and count the "pollutant_name" category

unique(air_sites_emissions_clean$pollutant_name)
length(unique(air_sites_emissions_clean$pollutant_name))
# Out:
#   [1] "Particulate Matter"
#   [2] "Particulate Matter 10"
#   [3] "Particulate Matter 2.5"
#   [4] "Nitrogen Oxide"
#   [5] "Carbon Monoxide"
#   [6] "Tetrachloroethylene (Perchloroethylene)"
#   [7] "Volatile Organic Compounds"
#   [8] "Hydrogen Sulfide"
#   [9] "Sulfur Dioxide"
#  [10] "Ammonia"
#  [11] "Biphenyl"
#  [12] "Lead"
#  [13] "Hexane"
#  [14] "Phenol"
#  [15] "Polychlorinated biphenyls (Aroclors)"
#  [16] "Benzene"
#  [17] "Acrolein"
#  [18] "Acetaldehyde"
#  [19] "Formaldehyde"
#  [20] "Hydrochloric acid (hydrogen chloride [gas only])"
#  [21] "Methanol"
#  [22] "m-Xylene"
#  [23] "Carbon Dioxide Equivalent"
#  [24] "Total Non-methane Org Cmpds"
#  [25] "Methylene chloride (Dichloromethane)"
#  [26] "Sulfuric Acid Mist"
#  [27] "Chloroform"
#  [28] "Hydrogen fluoride (hydrofluoric acid)"
#  [29] "Mercury Cmpds"
#  [30] "Chlorine"
#  [31] "Methyl chloroform (1,1,1-Trichloroethane)"
#  [32] "Total reduced sulfur"
#  [33] "Styrene"
#  [34] "Toluene"
#  [35] "Vinyl acetate"
#  [36] "Maleic anhydride"
#  [37] "Naphthalene"
#  [38] "Xylenes (isomers and mixtures)"
#  [39] "Manganese Cmpds"
#  [40] "1,4-Dichlorobenzene"
#  [41] "Ethylbenzene"
#  [42] "Chromium Cmpds"
#  [43] "Nickel Cmpds"
#  [44] "Methyl isobutyl ketone (Hexone)"
#  [45] "Methyl bromide (Bromomethane)"
#  [46] "Methyl tert-butyl ether"
#  [47] "Triethylamine"
#  [48] "Acetonitrile"
#  [49] "N,N-Dimethylformamide"
#  [50] "1,4-Dioxane (1,4-Diethyleneoxide)"
#  [51] "Ethylene oxide"
#  [52] "4,4-Methylenedianiline"
#  [53] "Glycol Ethers"
#  [54] "Cumene"
#  [55] "Methylmethacrylate"
#  [56] "Acrylic Acid"
#  [57] "Acrylonitrile"
#  [58] "Hexamethylene diisocyanate"
#  [59] "Hazardous Air Pollutant"
#  [60] "Methyl ethyl ketone (2-Butanone)"
#  [61] "Propionaldehyde"
#  [62] "Ethylene Glycol Methyl Ether"
#  [63] "Aniline"
#  [64] "Acetamide"
#  [65] "Total Hazardous Air Pollutants"
#  [66] "Cobalt Cmpds"
#  [67] "trichlorotrifluoroethane (CFC-113)"
#  [68] "Propylene dichloride (1,2-Dichloropropane)"
#  [69] "1,1,2,2-Tetrachloroethane"
#  [70] "Trichloroethylene"
#  [71] "Vinyl chloride"
#  [72] "Carbon disulfide"
#  [73] "Carbon tetrachloride"
#  [74] "Carbonyl sulfide"
#  [75] "Ethylidene dichloride (1,1-Dichloroethane)"
#  [76] "Ethylene glycol"
#  [77] "4,4-Methylenediphenyl diisocyanate (MDI)"
#  [78] "Dibutyl phthalate"
#  [79] "Arsenic Cmpds"
#  [80] "Quinone"
#  [81] "Phosphorus"
#  [82] "Coke Oven Emissions"
#  [83] "Beryllium Cmpds"
#  [84] "Selenium Cmpds"
#  [85] "Antimony Cmpds"
#  [86] "Epichlorohydrin (1-Chloro-2,3-epoxypropane)"
#  [87] "o-Xylene"
#  [88] "p-Xylene"
#  [89] "Bis(2-ethylhexyl)phthalate (DEHP)"
#  [90] "Ethyl acrylate"
#  [91] "Dimethyl phthalate"
#  [92] "Hydrazine"
#  [93] "Phosphine"
#  [94] "Methyl chloride (Chloromethane)"
#  [95] "Nitrobenzene"
#  [96] "4-Nitrophenol"
#  [97] "Acetophenone"
#  [98] "Cadmium Cmpds"
#  [99] "Chlorobenzene"
# [100] "Ethylene dichloride (1,2-Dichloroethane)"
# [101] "2,2,4-Trimethylpentane"
# [102] "Diethanolamine"
# [103] "2,4-Toluene diisocyanate"
# [104] "1,3-Butadiene"
# [105] "Ethyl chloride (Chloroethane)"
# [106] "Hydrobromic acid"
# [107] "Pentachlorophenol"
# [108] "Hexachlorobenzene"
# [109] "4,6-Dinitro-o-cresol"
# [110] "2,4-Dinitrotoluene"
# [111] "Captan"
# [112] "Acrylamide"
# [113] "Fluorides Total"
# [114] "Quinoline"
# [115] "Dibenzofuran"
# [116] "Polycyclic Org Matter"
# [117] "1,1,2-Trichloroethane"
# [118] "Propylene oxide"
# [119] "1,2,4-Trichlorobenzene"
# [120] "2,4,6-Trichlorophenol"
# [121] "Cresols/Cresylic acid (mixed isomers)"
# [122] "Dimethyl sulfate"
# [123] "2,4-Dinitrophenol"
# [124] "Ethylene dibromide (Dibromoethane)"
# [125] "Chloroacetic acid"
# [126] "Phthalic anhydride"
# [127] "N,N-Dimethylaniline"
# [128] "Hydroquinone"
# [129] "Isophorone"
# [130] "Benzyl Chloride"
# [131] "Cyanide Cmpds"
# [132] "o-Cresol"
# [133] "Methylhydrazine"
# [134] "p-Phenylenediamine"
# [135] "Phosgene"
# [136] "Catechol"
# [137] "2-Chloroacetophenone"
# [138] "Diazomethane"
# [139] "1,2-Diphenylhydrazine"
# [140] "Fine Mineral Fibers"
# [141] "Vinylidene chloride (1,1-Dichloroethylene)"
# [142] "Cellosolve Solvent"
# [143] "Benzidine"
# [144] "alpha methyl styrene"
# [1] 144

# %%
# Select only relevant columns
air_sites_emissions_clean <- air_sites_emissions_clean %>%
    select(emissions_year, emission_value, icis_id, pollutant_name)

# %%
write.csv(
  air_sites_emissions_clean, "/home/user/Capstone/data_center_research/data/processed/air_sites_emissions_clean.csv",
  row.names = FALSE
)

# %%
list.files("processed")
# Out:
# character(0)
